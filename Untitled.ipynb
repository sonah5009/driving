# %%
from pynq_dpu import DpuOverlay

overlay = DpuOverlay("../dpu/dpu.bit")
overlay.load_model("../xmodel/tiny-yolov3_coco_256.xmodel")
dpu = overlay.runner

# %%
from test_visualization import test_video_visualization, test_single_frame_visualization

# %%
test_single_frame_visualization(
    dpu,
    camera_index=0,
    output_video_path='output_lane_prediction.mp4',
    max_frames=100,
    save_png_interval=0.5,
    png_output_dir="output_frames"
)
# Out:
# [ WARN:0] global ./modules/videoio/src/cap_gstreamer.cpp (616) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 실시간 카메라 모드로 실행 중... (최대 100프레임)
# 동영상 저장 경로: output_lane_prediction.mp4
# PNG 저장 간격: 0.5초
# PNG 저장 디렉토리: output_frames
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 0개 값 평균 사용 (0.00°)
# PNG 저장: output_frames/frame_0000_time_1752060189.0s.png
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 0개 값 평균 사용 (0.00°)
# PNG 저장: output_frames/frame_0001_time_1752060190.5s.png
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 0개 값 평균 사용 (0.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 0개 값 평균 사용 (0.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 0개 값 평균 사용 (0.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 기본값 사용 (0.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 기본값 사용 (0.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 기본값 사용 (0.00°)
# DPU 초기화 중...
# ...

# %%
test_video_visualization(dpu, max_frames=50, camera_index=0)
# Out:
# [ WARN:0] global ./modules/videoio/src/cap_gstreamer.cpp (616) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 실시간 카메라 모드로 실행 중... (ESC 키로 종료)
# DPU 초기화 중...
# DPU 초기화 완료
# Lateral error: -0.781m, Heading error: 5.3°
# Lane center: 46.8, Image center: 128.0
# Steering: -1.75°, Speed: 29.7
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 1개 값 평균 사용 (-1.75°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 1개 값 평균 사용 (-1.75°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 1개 값 평균 사용 (-1.75°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 1개 값 평균 사용 (-1.75°)
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 1개 값 평균 사용 (-1.75°)
# DPU 초기화 중...
# DPU 초기화 완료
# Lateral error: -0.845m, Heading error: 36.9°
# Lane center: 44.5, Image center: 128.0
# Steering: 5.13°, Speed: 19.2
# 스무딩 적용: 5.13° → 3.76°
# DPU 초기화 중...
# DPU 초기화 완료
# 차선을 찾을 수 없습니다.
# 차선 미검출: 이전 2개 값 평균 사용 (1.00°)
# DPU 초기화 중...
# DPU 초기화 완료
# ...
